# %%
#04 그래프그리기 
#엔스콤 4분할 그래프 살펴보기 
#이 그래프는 영국의 프랭크 엔스콤이 데이터를 시각화하지 않고 수치만 
#확인할 때 발생할 수 있는 함정을 보여주기 위한 그래프이다. 
#4개의 데이터 그룹은 평균, 분산과 같은 수치값이나 상관관계, 회귀선이 같다는 특징이 있다. 
#그래스 이런 결과만 보고 데이터그룹I,II,III,IV의 데이터는 같을 것이다라고 착각할 수 있다. 
#하지만 데이터 그룹을 시각화하면 서로 다른 데이터 패턴을 가지고 있음을 알 수 있다. 
import seaborn as sns 

anscombe = sns.load_dataset('anscombe')
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#anscombe데이터프레임의 dataset열에서 데이터값이 I인것만 추출
dataset_1 = anscombe[anscombe['dataset'] == 'I']
plt.plot(dataset_1['x'], dataset_1['y'])

# %%
#만약 점으로 그래프를 그리려면 o를 세번째 인자로 전달
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %%
#1)전체 그래프가 위치할 기본 툴을 만든다.
#2)그래프를 그려 넣을 그래프 격자를 만든다.
#3)격자에 그래프를 하나씩 추가. 그래프가 추가되는 순서는 왼쪽에서 오른쪽
#4)만약 격자의 첫번째 행이 꽉 차면 두번째 행에 그래프가 그려진다. 
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

#그래프 격자가 위치할 기본 틀을 만든다.
fig = plt.figure()

# %%
#기본틀에 격자를 추가한다.
axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

# %%
#plot메서드에 데어터를 전달하여 그래프를 그린다. 
#그래프를 확인하려면 fig를 반드시 입력해야 한다.
#점의 색상은 매번 실행할 때마다 달라질 수 있다.
axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

fig

# %%
#구분하기 쉽게 제목을 추가해 본다. (제목이 안보이면 오른쪽 상단 차트 아이콘을 클릭해본다.)
axes1.set_title('dataset_1')
axes2.set_title('dataset_2')
axes3.set_title('dataset_3')
axes4.set_title('dataset_4')

fig

# %%
#기본 틀(fig)에도 제목을 추가해 본다.  (제목이 안보이면 오른쪽 상단 차트 아이콘을 클릭해본다.)
fig.suptitle("Anscombe Data")

fig

# %%
#각 그래프의 이름과 숫자가 겹쳐 보인다. 
#이런 경우는 tight_layout메서드를 호출하여 각 그래프의 레이아웃을 조절할 수 있다.
fig.tight_layout()

fig

# %%
#4-2 matplotlib라이브러리 자유자재로 사용하기
#기초 그래프 그리기
import seaborn as sns
tips = sns.load_dataset('tips')
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %%
#변수 하나만 사용해서 그린 그래프는 일변량그래프라고 한다. 
import matplotlib.pyplot as plt 
fig = plt.figure()
axes1 = fig.add_subplot(1,1,1)

# %%
#x축의 간격은 bins인자값으로 조정할 수 있다. 
#bins인자값을 10으로 지정하면 x축의 간격을 1으로 조정할 수 있다. 
axes1.hist(tips['total_bill'], bins=10)
axes1.set_title('Hisogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')

fig

# %%
#산점도 그래프는 변수 2개를 사용해서 만드는 그래프이며
#변수 2개를 사용하기 때문에 '이변량 그래프'라고 부른다. 
scatter_plot = plt.figure() 
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'], tips['tip'])
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
#박스그래프는 이산형변수와 연속형 변수를 함께 사용하는 그래프이다.
#이산형 변수란 Female, Male과 같이 명확하게 구분되는 값으 의미한다.
#연속형 변수란 Tip과 같이 명확하게 셀 수 없는 범위의 값을 의미한다. 

boxplot = plt.figure() 
axes1 = boxplot.add_subplot(1,1,1)

axes1.boxplot([tips[tips['sex'] == 'Female']['tip'],
                tips[tips['sex'] == 'Male']['tip']],
                labels=['Female','Male'])
axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %%
#다변량 그래프 그리기
#3개 이상의 변수를 사용한 그래프는 '다변량 그래프'라고 한다. 

#Female, Male과 같은 문자는 그래프의 색상을 지정하는 값으로
#사용할 수가 없다. 그래서 0,1과 같은 숫자로 바꾸어야 한다. 
#성별에 따라 0과 1을 반환하도록 함수 정의 
def recode_sex(sex):
    if sex == 'Female':
        return 0
    else:
        return 1 

#recode_sex함수를 브로드캐스팅하기 위해 apply()메서드 사용
#다중 행에 함수를 적용할 때 apply()메서드 사용 
tips['sex_color'] = tips['sex'].apply(recode_sex)

#테이블당 인원도 산점도에 추가 
#테이블당 인원 수는 점의 크기로 표현하면 적당하다.
#s는 점의 크기(size)를, c는 점의 색상(color)을 의미한다.  
scatter_plot = plt.figure() 
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x=tips['total_bill'],
    y=tips['tip'],
    s=tips['size'] * 10,
    c=tips['sex_color'],
    alpha=0.5
)
axes1.set_title("Total Bill vs Tip Colored by Sex and Sized by Size")
axes1.set_xlabel('전체식대')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')
# C:\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49885 (\N{HANGUL SYLLABLE SIG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#seaborn라이브러리를 사용하면 matplotlib보다 좀 더
#화려한 그래프를 그릴 수 있다.
import pandas as pd 
import matplotlib.pyplot as plt 
from matplotlib import font_manager, rc 
import seaborn as sns 

import platform

from matplotlib import font_manager, rc
#-기호는 기존 폰트를 사용
plt.rcParams['axes.unicode_minus'] = False 
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system')

tips = sns.load_dataset('tips')
ax = sns.displot(tips['total_bill'])

# %%
#displot메서드를 사용하면 히스토그램과 밀집도 그래프를 같이 그린다.
#만약 밀집도 그래프를 제외하고 싶다면 kde인자를 False로 지정한다. 
#밀집도 그래프는 주어진 데이터를 정규화시켜 넓이가 1이 되도록 그린 그래프이다.
ax = plt.subplots()
ax = sns.displot(tips['total_bill'], kde=True)
ax.set_titles('전체 금액')
ax.set_xlabels('전체 식대')
ax.set_ylabels('Frequency')

# %%
ax = plt.subplots()
ax = sns.displot(tips['total_bill'], kde=False)
ax.set_titles('Total Bill Histogram')
ax.set_xlabels('Total Bill')
ax.set_ylabels('Frequency')

# %%
import platform

from matplotlib import font_manager, rc

plt.rcParams['axes.unicode_minus'] = False 

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf'
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system')


#밀집도 그래프만 나타내려면 hist인자를 False로 지정한다.
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], hist=False)
ax.set_title('전체 금액 밀도')
ax.set_xlabel('전체 지불 금액')
ax.set_ylabel('Unit 가능성')
# Out:
# C:\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Unit 가능성')

# %%
#실무 환경에서는 데이터 시각화를 더 효율적으로 하기 위해 
#여러 그래프를 한번에 출력하는 경우가 많다. 
#다음은 히스토그램과 밀집도를 그리는 distplot메서드에 rug인자를 
#추가하여 양탄자(rug)그래프까지 그린 것이다. 
#양탄자 그래프는 그래프의 축에 동일한 길이의 직선을 붙여
#데이터 밀집 정도를 표현한 그래프이다. 
ax = plt.subplots()
ax = sns.displot(tips['total_bill'], kde=True, rug=True)

ax.set_xlabels('Total Bill')

# %%
#count그래프는 이산값(명확하게 구분되는 값)을 나타낸 그래프이다. 
#다음은 countplot메서드에 tips데이터프레임의 
#day열 데이터를 넣어 count그래프를 그린 것이다. 
ax = plt.subplots()
ax = sns.countplot('day', data=tips)
ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# C:\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Frequency')

# %%
#다양한 종류의 이변량 그래프 그리기
#산점도 그래프를 그리려면 seaborn라이브러리의 
#regplot메서드를 사용해야 한다. 
#regplot메서드를 사용하면 산점도 그래프와 회귀선을 함께 그릴 수 있다. 
#만약 회귀선을 제거하려면 fit_reg인자를 False로 지정한다. 
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
#회귀선을 제거하려면 fig_reg인자를 False값으로 지정한다.
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
#산점도 그래프와 히스토그램을 한번에 그려주는 jointplot메서드를
#사용해 본다. x,y인자에 원하는 열이름을 지정하고 
#data인자값으로 데이터프레임을 지정하면 된다. 

joint = sns.jointplot(x='total_bill', y='tip', data=tips)
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
#산점도 그래프는 점이 겹쳐 보일 경우 점을 구분하기 어렵다는 단점이 있다.
#육각 그래프I(hexbin)을 사용하면 된다. 
#육각 그래프는 2차원 표면에 육각형으로 데이터를 쌓아서 표현한다.
#그래서 특정 데이터의 개수가 많아지면 점점 진한 색으로 표현된다.
joint = sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
#이차원 밀집도 그리기 
#이차원 밀집도는 kdeplot메서드로 만들 수 있다. 
#shade인자값을 True로 지정하면 그래프에 음영 효과를 줄 수 있다.
ax = plt.subplots()
ax = sns.kdeplot(data=tips['total_bill'],
    data2=tips['tip'],
    shade=True)

ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('tip')
# Out:
# C:\Python39\lib\site-packages\seaborn\distributions.py:1681: FutureWarning: Use `x` and `y` rather than `data` `and `data2`
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'tip')

# %%
#바그래프 그리기
#바 그래프는 지정한 변수의 평균을 계산하여 그릴 수 있다. 
#다음은 시간에 따라 지불한 비용의 평균을 바 그래프로 나타낸 것이다.
ax = plt.subplots()
ax = sns.barplot(x='time', y='total_bill', data=tips)
ax.set_title('Bar plot of average total bill for time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Average total bill')
# Out:
# Text(0, 0.5, 'Average total bill')

# %%
#박스 그래프 그리기
#박스 그래프는 최소값, 1분위수, 중간값, 3분위수,
#최대값, 이상치 등 다양한 통계량을 한번에 표현하는 그래프이다.
ax = plt.subplots()
ax = sns.boxplot(x='time', y='total_bill', data=tips)
ax.set_title('Boxplot of total bill by time of day')
ax.set_xlabel("Time of day")
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
#박스 그래프는 다양한 통계 수치를 확인하기 위해 자주 사용하는 그래프이다.
#하지만 데이터 분산이 모호하게 표현된다. 
#이런 경우 박스 그래프에 커널 밀도를 추정한 바이올린 그래프를 
#사용하면 된다.
ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', data=tips)
ax.set_title('Boxplot of total bill by time of day')
ax.set_xlabel("Time of day")
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
#관게 그래프 그리기
#관계 그래프는 지금까지 설명한 그래프를 종합한 그래프이다.
fig = sns.pairplot(tips)

# %%
#이때 관계 그래프는 중복된 정보가 표현된다는 단점이 있따. 
#즉, 관계 그래프의 절반(대각선을 기준으로)은 나머지 절반과 같다. 
#이런 경우 중복된 그래프가 그려지는 위치를 직접 지정하여 원하는 
#그래프로 교체하면 된다. 
#map_upper메서드를 대각선을 기준으로 위쪽에 그릴 그래프를 지정한다.
#반대로 map_lower메서드는 대각선을 기준으로 아래쪽에 그릴 그래프를 지정한다.
#map_diag는 대각선을 중심으로 그래프를 그린다. 
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.distplot, rug=True)
plt.show()
# Out:
# C:\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Python39\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# C:\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
#4-4 데이터프레임과 시리즈로 그래프 그리기
#히스토그램을 그려본다.
import matplotlib.pyplot as plt 

ax = plt.subplots()
ax = tips['total_bill'].plot.hist()

# %%
#투명도를 조절하려면 hist메서드의 alpha, bins, ax인잘르 사용하면 된다. 
#alpha는 투명도, bins는 x축의 간격이다.
fig, ax = plt.subplots()
ax = tips[['total_bill','tip']].plot.hist(alpha=0.5, bins=20, ax=ax)

# %%
#밀집도, 산점도 그래프, 육각 그래프는 각각 
#kde, scatter, hexbin메서드를 사용하여 그릴 수 있다.
ax = plt.subplots()
ax = tips['tip'].plot.kde()
# Out:
# C:\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fig, ax = plt.subplots()
ax = tips.plot.scatter(x='total_bill', y='tip', ax=ax)

# %%
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x='total_bill', y='tip', ax=ax)

# %%
#이때 육각 그래프의 육각형 크기는 gridsize인자를 사용하여
#변경할 수 있다.
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x='total_bill', y='tip', gridsize=10, ax=ax)

# %%
#다음은 box메서드를 사용하여 그린 박스 그래프이다.
fig, ax = plt.subplots()
ax = tips.plot.box(ax=ax)

# %%
#4-5 seaborn라이브러리로 그래프 스타일 설정하기
#seaborn라이브러리로 만든 그래프의 스타일은 set_style메서드를 사용하여
#바꿀 수 있다. 
#seaborn라이브러리 스타일은 darkgrid, whitegrid, dark, white, ticks
fig, ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', 
    hue='sex', data=tips, split=True)

# %%
#whitegrid로 스타일을 지정 
sns.set_style('whitegrid')
fig, ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill',
    hue='sex', data=tips, split=True)

# %%
#for문을 사용해서 모든 스타일을 하나씩 적용한 그래프
fig = plt.figure()

seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']

for idx, style in enumerate(seaborn_styles):
    plot_position = idx + 1 
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot(x='time', y='total_bill', data=tips, ax=ax)
        violin.set_title(style)

fig.tight_layout()
